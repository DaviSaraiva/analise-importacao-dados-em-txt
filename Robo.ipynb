# %%
import pandas as pd
import sqlalchemy
#bibliteca para criar conexao

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\programdata\anaconda3\lib\site-packages (2.8.6)

# %%
engine = sqlalchemy.create_engine('postgres+psycopg2://postgres:1234567@192.168.15.23:5432/estudantes')

# %%
df= pd.read_sql_table('pessoas',engine)

# %%
df.head()
# Out:
#                                      id                           nome  \
# 0  d49d1803-7729-4fc3-b6b8-80f17cbdd72e  Kairo Emannoel Costa de Souza
# 1  9d978984-9ae1-4c05-b3c2-b3aa44340ad0                Marcelo Ricardo
# 2  940ba039-c77f-4215-aebc-bc76cee9c7a7                Marcelo Ricardo
#
#       genero             cpf  escolaridade          telefone  \
# 0  masculino  064.978.763-32     graduacao  (86) 9 9939-0000
# 1  masculino  377.346.700-16     graduacao  (98) 9 8209-6280
# 2  masculino  477.437.200-55  posgraduacao  (98) 9 8209-6280
#
#            whatsapp serieperiodo                    instituicao cidadeescola  \
# 0  (86) 9 9999-9999           11  IFPI- INSTITUTO FEDERAL DO PI     Teresina
# 1  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR     Teresina
# 2  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR        Timon
#
#    ... tpcomprovantematricula  turno        numregistro anodeconclusao  \
# 0  ...      atestadomatricula  tarde               None           None
# 1  ...                 boleto  manha  45455445445545454           2020
# 2  ...      atestadomatricula  manha  45455445445545454           None
#
#          cep numero              logradouro             bairro  localidade  uf
# 0  64028-420     45  Rua PAULO BONA ANDRADE      Santo Antônio    Teresina  PI
# 1  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
# 2  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
#
# [3 rows x 28 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                                      id                           nome  \
# 0  d49d1803-7729-4fc3-b6b8-80f17cbdd72e  Kairo Emannoel Costa de Souza
# 1  9d978984-9ae1-4c05-b3c2-b3aa44340ad0                Marcelo Ricardo
# 2  940ba039-c77f-4215-aebc-bc76cee9c7a7                Marcelo Ricardo
#
#       genero             cpf  escolaridade          telefone  \
# 0  masculino  064.978.763-32     graduacao  (86) 9 9939-0000
# 1  masculino  377.346.700-16     graduacao  (98) 9 8209-6280
# 2  masculino  477.437.200-55  posgraduacao  (98) 9 8209-6280
#
#            whatsapp serieperiodo                    instituicao cidadeescola  \
# 0  (86) 9 9999-9999           11  IFPI- INSTITUTO FEDERAL DO PI     Teresina
# 1  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR     Teresina
# 2  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR        Timon
#
#    ... tpcomprovantematricula  turno        numregistro anodeconclusao  \
# 0  ...      atestadomatricula  tarde               None           None
# 1  ...                 boleto  manha  45455445445545454           2020
# 2  ...      atestadomatricula  manha  45455445445545454           None
#
#          cep numero              logradouro             bairro  localidade  uf
# 0  64028-420     45  Rua PAULO BONA ANDRADE      Santo Antônio    Teresina  PI
# 1  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
# 2  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
#
# [3 rows x 28 columns]>

# %%
df= pd.read_sql_query('select * from pessoas', engine)

# %%
df.head()
# Out:
#                                      id                           nome  \
# 0  d49d1803-7729-4fc3-b6b8-80f17cbdd72e  Kairo Emannoel Costa de Souza
# 1  9d978984-9ae1-4c05-b3c2-b3aa44340ad0                Marcelo Ricardo
# 2  940ba039-c77f-4215-aebc-bc76cee9c7a7                Marcelo Ricardo
#
#       genero             cpf  escolaridade          telefone  \
# 0  masculino  064.978.763-32     graduacao  (86) 9 9939-0000
# 1  masculino  377.346.700-16     graduacao  (98) 9 8209-6280
# 2  masculino  477.437.200-55  posgraduacao  (98) 9 8209-6280
#
#            whatsapp serieperiodo                    instituicao cidadeescola  \
# 0  (86) 9 9999-9999           11  IFPI- INSTITUTO FEDERAL DO PI     Teresina
# 1  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR     Teresina
# 2  (87) 7 7887-8787            8  ICEV-INSTI DE ENSINO SUPERIOR        Timon
#
#    ... tpcomprovantematricula  turno        numregistro anodeconclusao  \
# 0  ...      atestadomatricula  tarde               None           None
# 1  ...                 boleto  manha  45455445445545454           2020
# 2  ...      atestadomatricula  manha  45455445445545454           None
#
#          cep numero              logradouro             bairro  localidade  uf
# 0  64028-420     45  Rua PAULO BONA ANDRADE      Santo Antônio    Teresina  PI
# 1  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
# 2  65300-275     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
#
# [3 rows x 28 columns]

# %%
#criando uma query com varias colunas
query= '''
SELECT u."pessoaId", p.id, t."requestStatus",p.nome, p.genero, p.cpf,
                       p.escolaridade, p.telefone, p.whatsapp,
                       p.serieperiodo, p.instituicao, p.cidadeescola,
                       p.ufescola, p.tipodocumento, p.rg, p.orgaoemissor,
                       p.registrocnh, p.datanascimento, p.nomemae, p.nomepai,
                       p.tpcomprovantematricula, p.turno, p.numregistro, p.anodeconclusao,
                       p.cep, p.numero, p.logradouro, p.bairro,
                       p.localidade, p.uf  FROM "user" AS u  INNER JOIN
                       "pessoas" AS p
                       ON(u."pessoaId"=p.id) INNER JOIN
                       "transaction" AS t ON t."userId"=u.id
                       inner join "payment" as 
					   pay on t."paymentId"=pay.id
					   inner join "documents" as doc ON 
					   t."documentId" =doc.id
                       where
                       t."requestStatus"='analise' and
                       pay."paymentStatus"='paid' and 
					   doc.completeupdate =false
'''

# %%
df= pd.read_sql_query(query,engine)

# %%
df.head()
# Out:
#                                pessoaId                                    id  \
# 0  d49d1803-7729-4fc3-b6b8-80f17cbdd72e  d49d1803-7729-4fc3-b6b8-80f17cbdd72e
# 1  9d978984-9ae1-4c05-b3c2-b3aa44340ad0  9d978984-9ae1-4c05-b3c2-b3aa44340ad0
# 2  940ba039-c77f-4215-aebc-bc76cee9c7a7  940ba039-c77f-4215-aebc-bc76cee9c7a7
#
#   requestStatus                           nome     genero             cpf  \
# 0       analise  Kairo Emannoel Costa de Souza  masculino  064.978.763-32
# 1       analise                Marcelo Ricardo  masculino  377.346.700-16
# 2       analise                Marcelo Ricardo  masculino  477.437.200-55
#
#    escolaridade          telefone          whatsapp serieperiodo  ...  \
# 0     graduacao  (86) 9 9939-0000  (86) 9 9999-9999           11  ...
# 1     graduacao  (98) 9 8209-6280  (87) 7 7887-8787            8  ...
# 2  posgraduacao  (98) 9 8209-6280  (87) 7 7887-8787            8  ...
#
#   tpcomprovantematricula  turno        numregistro anodeconclusao        cep  \
# 0      atestadomatricula  tarde               None           None  64028-420
# 1                 boleto  manha  45455445445545454           2020  65300-275
# 2      atestadomatricula  manha  45455445445545454           None  65300-275
#
#   numero              logradouro             bairro  localidade  uf
# 0     45  Rua PAULO BONA ANDRADE      Santo Antônio    Teresina  PI
# 1     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
# 2     15       Rua José Ferreira  Vila Edmundo Rios  Santa Inês  MA
#
# [3 rows x 30 columns]

# %%
for index in range(0,len(df)):
    nome =df.loc[index,'nome'].ljust(90)[:90]
    cpf =df.loc[index,'cpf'].replace(".", "").replace("-", "").ljust(11)[:11]
    genero =df.loc[index,'genero'].replace(".", "").replace("-", "").ljust(1)[:1]

    arquivo = open('teste.txt', 'a')
    arquivo.write("{NOME}{CPF}{GENERO}\n".format(CPF=cpf,ID=id,NOME=nome,GENERO=genero))
    arquivo.close()
